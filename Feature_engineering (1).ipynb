# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('/content/train (1).csv')
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
train.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
x= train.iloc[:,0:20]
y=train.iloc[:,-1]

# %% [markdown]
# **FEATURE EXTRACTION USING UNIVARIATE STATISTICAL TEST**
#   HERE WE ARE USING CHI SQUARE

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
best_feature = SelectKBest(score_func=chi2, k=10)
fit = best_feature.fit(x,y)

# %%
df_score = pd.DataFrame(fit.scores_)
df_columns = pd.DataFrame(x.columns)

f_score = pd.concat([df_columns,df_score],axis =1)
f_score.columns = ['column','score']

print(f_score.nlargest(10,'score'))
# Out:
#            column          score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# **TREE BASED FEATURE SELECTION**

# %%
import xgboost

model = xgboost.XGBClassifier()
model.fit(x,y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
model.feature_importances_
# Out:
# array([0.13539864, 0.00565321, 0.01685527, 0.01848102, 0.02126197,
#        0.00948505, 0.01591107, 0.01888023, 0.02183507, 0.02243848,
#        0.02318871, 0.09381714, 0.08440401, 0.44293442, 0.01251564,
#        0.01900865, 0.01205176, 0.00328287, 0.01472708, 0.00786969],
#       dtype=float32)

# %%
a = []
a = model.feature_importances_
df2 = f_score.copy()
df2['ft'] = pd.Series(a)
df2
# Out:
#            column          score        ft
# 0   battery_power   14129.866576  0.135399
# 1            blue       0.723232  0.005653
# 2     clock_speed       0.648366  0.016855
# 3        dual_sim       0.631011  0.018481
# 4              fc      10.135166  0.021262
# 5          four_g       1.521572  0.009485
# 6      int_memory      89.839124  0.015911
# 7           m_dep       0.745820  0.018880
# 8       mobile_wt      95.972863  0.021835
# 9         n_cores       9.097556  0.022438
# 10             pc       9.186054  0.023189
# 11      px_height   17363.569536  0.093817
# 12       px_width    9810.586750  0.084404
# 13            ram  931267.519053  0.442934
# 14           sc_h       9.614878  0.012516
# 15           sc_w      16.480319  0.019009
# 16      talk_time      13.236400  0.012052
# 17        three_g       0.327643  0.003283
# 18   touch_screen       1.928429  0.014727
# 19           wifi       0.422091  0.007870

# %%
df2.nlargest(10,'ft')
# Out:
#            column          score        ft
# 13            ram  931267.519053  0.442934
# 0   battery_power   14129.866576  0.135399
# 11      px_height   17363.569536  0.093817
# 12       px_width    9810.586750  0.084404
# 10             pc       9.186054  0.023189
# 9         n_cores       9.097556  0.022438
# 8       mobile_wt      95.972863  0.021835
# 4              fc      10.135166  0.021262
# 15           sc_w      16.480319  0.019009
# 7           m_dep       0.745820  0.018880

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(criterion= 'log_loss')
rfc.fit(x,y)
# Out:
# RandomForestClassifier(criterion='log_loss')

# %%
b=[]

b =rfc.feature_importances_

# %%
df3 = f_score.copy()
df3['FI RBF'] = pd.Series(b)
df3.nlargest(10,'FI RBF')
# Out:
#            column          score    FI RBF
# 13            ram  931267.519053  0.537842
# 0   battery_power   14129.866576  0.073655
# 11      px_height   17363.569536  0.054993
# 12       px_width    9810.586750  0.053812
# 8       mobile_wt      95.972863  0.033470
# 6      int_memory      89.839124  0.030880
# 15           sc_w      16.480319  0.025104
# 16      talk_time      13.236400  0.024984
# 2     clock_speed       0.648366  0.023913
# 10             pc       9.186054  0.023904

# %%
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
plt.figure(figsize = (15,10))
cf =train.corr()
import seaborn as sns
sns.heatmap(cf,annot =True)
# Out:
# <Axes: >

# %% [markdown]
# 4.RECURSIVE FEATURE ELIMINATION

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)
model = LogisticRegression(max_iter =1000)
rfe = RFE(model, n_features_to_select=10)
fit =rfe.fit(X_scaled, y)

# %%
sel_features = fit.support_
feature_rank = fit.ranking_

# %%
feature_name =x.columns[sel_features]
print(feature_name)
df4 = pd.DataFrame({
    'Feature'  : x.columns,
    'Ranking' :feature_rank
})
df4 = df4.sort_values(by ='Ranking')
print(df4)
# Out:
# Index(['battery_power', 'int_memory', 'mobile_wt', 'n_cores', 'px_height',
#        'px_width', 'ram', 'sc_h', 'touch_screen', 'wifi'],
#       dtype='object')
#           Feature  Ranking
# 0   battery_power        1
# 14           sc_h        1
# 13            ram        1
# 12       px_width        1
# 11      px_height        1
# 18   touch_screen        1
# 8       mobile_wt        1
# 9         n_cores        1
# 6      int_memory        1
# 19           wifi        1
# 7           m_dep        2
# 3        dual_sim        3
# 2     clock_speed        4
# 4              fc        5
# 5          four_g        6
# 17        three_g        7
# 16      talk_time        8
# 15           sc_w        9
# 10             pc       10
# 1            blue       11

# %% [markdown]
# 5 LASSO
# Tries to cut off the selected features

# %%
from sklearn.linear_model import Lasso
model =Lasso(alpha =0.02)
model.fit(x,y)
importance = np.abs(model.coef_)

# %%
df5 = pd.DataFrame({
    'Feature'  : x.columns,
    'Importance' :importance
})
df5 = df5.sort_values(by ='Importance',ascending=False)
print(df5)
# Out:
#           Feature  Importance
# 13            ram    0.000947
# 8       mobile_wt    0.000868
# 6      int_memory    0.000798
# 0   battery_power    0.000511
# 12       px_width    0.000279
# 11      px_height    0.000275
# 10             pc    0.000043
# 7           m_dep    0.000000
# 5          four_g    0.000000
# 9         n_cores    0.000000
# 1            blue    0.000000
# 4              fc    0.000000
# 3        dual_sim    0.000000
# 2     clock_speed    0.000000
# 14           sc_h    0.000000
# 15           sc_w    0.000000
# 16      talk_time    0.000000
# 17        three_g    0.000000
# 18   touch_screen    0.000000
# 19           wifi    0.000000

# %% [markdown]
# 6 Mutual Information

# %%
from sklearn.feature_selection import mutual_info_classif
mi = mutual_info_classif(x,y)
mi_df = pd.DataFrame({
    'Feature'  : x.columns,
    'Mutual Information' :mi})
mi_df = mi_df.sort_values(by = 'Mutual Information',ascending = False)
print(mi_df)
# Out:
#           Feature  Mutual Information
# 13            ram            0.849883
# 12       px_width            0.028519
# 11      px_height            0.023997
# 0   battery_power            0.022974
# 10             pc            0.017208
# 6      int_memory            0.016157
# 4              fc            0.015352
# 8       mobile_wt            0.011307
# 7           m_dep            0.008364
# 15           sc_w            0.004680
# 9         n_cores            0.004431
# 3        dual_sim            0.002636
# 5          four_g            0.000000
# 1            blue            0.000000
# 2     clock_speed            0.000000
# 14           sc_h            0.000000
# 16      talk_time            0.000000
# 17        three_g            0.000000
# 18   touch_screen            0.000000
# 19           wifi            0.000000

# %% [markdown]
# 7 PRINCIPLE COMPONENT ANALYSIS

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
X_new = pca.fit_transform(x)

# %%
components = pca.components_
pca_df = pd.DataFrame(components,columns = x.columns)
print(pca_df)
for i in range(pca.n_components):
  component = pca_df.iloc[i]
  print(f"Principal Component {i+1} Feature Importance:")
  print(component.abs().sort_values(ascending = False))
  print("/n")
# Out:
#    battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0      -0.000347  0.000012     0.000003  0.000019  0.000061  0.000003
# 1       0.010388 -0.000025    -0.000021 -0.000004 -0.000067 -0.000007
# 2       0.999442  0.000014     0.000021 -0.000048  0.000329  0.000017
# 3       0.031713 -0.000059     0.000014  0.000053  0.000082  0.000045
# 4       0.000157  0.000128    -0.000283  0.000121 -0.003029  0.000235
# 5       0.000192  0.001087     0.000323 -0.000465 -0.007899  0.000234
# 6      -0.000562 -0.000378    -0.000583 -0.001722  0.515805 -0.000839
# 7       0.000713 -0.001294     0.001137  0.002982  0.024368  0.005072
# 8       0.000184  0.000087    -0.003497 -0.002654  0.001125  0.002387
# 9       0.000096 -0.002006    -0.006207  0.002478 -0.370909  0.000079
#
#    int_memory         m_dep  mobile_wt   n_cores        pc  px_height  \
# 0    0.000548 -2.534142e-06  -0.000084  0.000010  0.000162  -0.009903
# ...

# %% [markdown]
# 8 VARIANCE THRESHOLD

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=.8)
X_neww = sel.fit_transform(x)
selected_f_mask = sel.get_support()

# %%
retained_feature = pd.DataFrame({
    'feature' : x.columns[selected_f_mask],
    'Variance': x.var()[selected_f_mask]
})
print(retained_feature)
# Out:
#                      feature      Variance
# battery_power  battery_power  1.930884e+05
# fc                        fc  1.884813e+01
# int_memory        int_memory  3.292670e+02
# mobile_wt          mobile_wt  1.253136e+03
# n_cores              n_cores  5.234197e+00
# pc                        pc  3.677592e+01
# px_height          px_height  1.969414e+05
# px_width            px_width  1.867964e+05
# ram                      ram  1.176644e+06
# sc_h                    sc_h  1.775143e+01
# sc_w                    sc_w  1.897820e+01
# talk_time          talk_time  2.985481e+01

# %% [markdown]
# 9 F_CLASSIF

# %%
from sklearn.feature_selection import SelectKBest,f_classif
selector = SelectKBest(score_func=f_classif,k=10)
x_fit = selector.fit(x,y)
xn = selector.fit_transform(x,y)

# %%
xn_score = pd.DataFrame(x_fit.scores_)
xn_colum = pd.DataFrame(x.columns)

f_score = pd.concat([xn_colum,xn_score],axis =1)
f_score.columns = ['column','score']
f_score.nlargest(10,'score')
# Out:
#            column        score
# 13            ram  3520.110824
# 0   battery_power    31.598158
# 12       px_width    22.620882
# 11      px_height    19.484842
# 8       mobile_wt     3.594318
# 6      int_memory     2.922996
# 9         n_cores     2.625415
# 14           sc_h     2.225984
# 15           sc_w     1.671000
# 16      talk_time     1.628811

# %%
xcc = sel.get_support()
f_features = pd.DataFrame({
    'feature' : x.columns[xcc],
    'Variance': x.var()[xcc]
})
print(f_features)
# Out:
#                      feature      Variance
# battery_power  battery_power  1.930884e+05
# fc                        fc  1.884813e+01
# int_memory        int_memory  3.292670e+02
# mobile_wt          mobile_wt  1.253136e+03
# n_cores              n_cores  5.234197e+00
# pc                        pc  3.677592e+01
# px_height          px_height  1.969414e+05
# px_width            px_width  1.867964e+05
# ram                      ram  1.176644e+06
# sc_h                    sc_h  1.775143e+01
# sc_w                    sc_w  1.897820e+01
# talk_time          talk_time  2.985481e+01

# %% [markdown]
# 10 BORUTA

# %%
# !pip install boruta
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
feat_selector = BorutaPy(model,n_estimators='auto',random_state=1)
feat_selector.fit(x.values,y.values)
# Out:
# BorutaPy(estimator=RandomForestClassifier(n_estimators=31,
#                                           random_state=RandomState(MT19937) at 0x7AA31B21E140),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x7AA31B21E140)

# %%
selected_feature_mask = feat_selector.support_
weakly_feat = feat_selector.support_weak_

s_names = x.columns[selected_f_mask]
print("selected_features", s_names)
# Out:
# selected_features Index(['battery_power', 'fc', 'int_memory', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time'],
#       dtype='object')

# %%
weak_feat = x.columns[weakly_feat]
print("selected_features", weak_feat)
# Out:
# selected_features Index([], dtype='object')
